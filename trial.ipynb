# %%
import os
from dotenv import load_dotenv
from google import genai
# import google.generativeai as genai

# Load environment variables
load_dotenv(dotenv_path=".env")

transcript='''[2025-03-27 18:37:19.810679] AGENT:
Hi I am Priya your assistant for booking your appointment or help you with queries related to your health

[2025-03-27 18:37:29.884768] USER:
Hello. My name is Harish. So I am

[2025-03-27 18:37:36.553604] AGENT:
Hello Harish, it's nice to meet you. How can I assist you today? Do you have a question about our hospital, need to book an appointment, or something else?

[2025-03-27 18:37:43.248756] USER:
Yeah. I need to book appointment of twelve AM tomorrow.

[2025-03-27 18:38:05.804583] USER:
I want to put one I want to work for doctor station.

'''

prompt = '''You are a precise JSON extractor for patient appointment information. Follow these guidelines:

1. Extract the following fields from the given conversation:
   - name: Full name of the patient (string)
   - phone: Patient's contact phone number (string)
   - doctor: Name of the doctor (string)
   - timeSlot: Scheduled appointment time (string)

2. Parsing Rules:
   - Be case-sensitive and exact in capturing information
   - Remove any extra whitespace
   - Standardize phone number format (e.g., XXX-XXX-XXXX)
   - If ANY required field is missing, return null for the entire JSON object

3. Output Format:
   {{
     "name": "Patient Name" or null,
     "phone": "Phone Number" or null,
     "doctor": "Doctor Name" or null,
     "timeSlot": "Appointment Time" or null
   }}

Example Input: "Hi, I want to book an appointment with Dr. Smith for John Doe at 2 PM tomorrow. His number is 555-1234."
Example Output: 
{{
  "name": "John Doe",
  "phone": "555-1234",
  "doctor": "Dr. Smith", 
  "timeSlot": "2 PM tomorrow"
}}

Now extract the information from this conversation:
"""{}"""'''.format(transcript)
genai.configure(api_key=os.genenv('GEMINI_API_KEY'))
model = genai.GenerativeModel('gemini-1.5-flash')
response = model.generate_content(prompt)
print(response.text)
    # return response.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 59
#       9 transcript='''[2025-03-27 18:37:19.810679] AGENT:
#      10 Hi I am Priya your assistant for booking your appointment or help you with queries related to your health
#      11
#    (...)     23
#      24 '''
#      26 prompt = '''You are a precise JSON extractor for patient appointment information. Follow these guidelines:
#      27
#      28 1. Extract the following fields from the given conversation:
#    (...)     57 Now extract the information from this conversation:
#      58 """{}"""'''.format(transcript)
# ---> 59 genai.configure(api_key=os.genenv('GEMINI_API_KEY'))
#      60 model = genai.GenerativeModel('gemini-1.5-flash')
#      61 response = model.generate_content(prompt)
#
# AttributeError: module 'google.genai' has no attribute 'configure'

# %%
tempelate = f'''You are a precise JSON extractor for patient appointment information. Follow these guidelines:

1. Extract the following fields from the given conversation:
    - name: Full name of the patient (string)
    - phone: Patient's contact phone number (string)
    - doctor: Name of the doctor (string)
    - timeSlot: Scheduled appointment time (string)

2. Parsing Rules:
    - Be case-sensitive and exact in capturing information
    - Remove any extra whitespace
    - Standardize phone number format (e.g., XXX-XXX-XXXX)
    - If ANY required field is missing, return null for the entire JSON object

3. Output Format:
    {{
      "name": "Patient Name" or null,
      "phone": "Phone Number" or null,
      "doctor": "Doctor Name" or null,
      "timeSlot": "Appointment Time" or null
    }}

Example Input: "Hi, I want to book an appointment with Dr. Smith for John Doe at 2 PM tomorrow. His number is 555-1234."
Example Output: 
{{
  "name": "John Doe",
  "phone": "555-1234",
  "doctor": "Dr. Smith", 
  "timeSlot": "2 PM tomorrow"
}}

Now extract the information from this conversation:
{transcript}
'''

# %%
tempelate='''You are a precise JSON extractor for patient appointment information. Follow these guidelines:

1. Extract the following fields from the given conversation:
   - name: Full name of the patient (string)
   - phone: Patient's contact phone number (string)
   - doctor: Name of the doctor (string)
   - timeSlot: Scheduled appointment time (string)

2. Parsing Rules:
   - Be case-sensitive and exact in capturing information
   - Remove any extra whitespace
   - Standardize phone number format (e.g., XXX-XXX-XXXX)
   - If ANY required field is missing, return null for the entire JSON object

3. Output Format:
   {{
     "name": "Patient Name" or null,
     "phone": "Phone Number" or null,
     "doctor": "Doctor Name" or null,
     "timeSlot": "Appointment Time" or null
   }}

Example Input: "Hi, I want to book an appointment with Dr. Smith for John Doe at 2 PM tomorrow. His number is 555-1234."
Example Output: 
{{
  "name": "John Doe",
  "phone": "555-1234",
  "doctor": "Dr. Smith", 
  "timeSlot": "2 PM tomorrow"
}}

Now extract the information from this conversation:
'''tempelate='''You are a precise JSON extractor for patient appointment information. Follow these guidelines:

1. Extract the following fields from the given conversation:
   - name: Full name of the patient (string)
   - phone: Patient's contact phone number (string)
   - doctor: Name of the doctor (string)
   - timeSlot: Scheduled appointment time (string)

2. Parsing Rules:
   - Be case-sensitive and exact in capturing information
   - Remove any extra whitespace
   - Standardize phone number format (e.g., XXX-XXX-XXXX)
   - If ANY required field is missing, return null for the entire JSON object

3. Output Format:
   {{
     "name": "Patient Name" or null,
     "phone": "Phone Number" or null,
     "doctor": "Doctor Name" or null,
     "timeSlot": "Appointment Time" or null
   }}

Example Input: "Hi, I want to book an appointment with Dr. Smith for John Doe at 2 PM tomorrow. His number is 555-1234."
Example Output: 
{{
  "name": "John Doe",
  "phone": "555-1234",
  "doctor": "Dr. Smith", 
  "timeSlot": "2 PM tomorrow"
}}

Now extract the information from this conversation:
'''

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 52
#      17 tempelate = f'''You are a precise JSON extractor for patient appointment information. Follow these guidelines:
#      18
#      19 1. Extract the following fields from the given conversation:
#    (...)     49 {transcript}
#      50 '''
#      51 prompt = PromptTemplate.from_template(tempelate)
# ---> 52 formatted_prompt = prompt.format(transcript=transcript)
#      53 chain = LLMChain(llm=llm, prompt=formatted_prompt, verbose=True)
#      55 # Get the result and extract the text from the dictionary
#
# File ~/Documents/voice-pipeline-agent-python/.venv/lib/python3.12/site-packages/langchain_core/prompts/prompt.py:185, in PromptTemplate.format(self, **kwargs)
#     176 """Format the prompt with the inputs.
#     177
#     178 Args:
#    (...)    182     A formatted string.
#     183 """
# ...

# %%
import os
from dotenv import load_dotenv

# %%
load_dotenv()
api_key = os.getenv('GEMINI_API_KEY')
if not api_key:
    raise ValueError("GOOGLE_API_KEY not found in environment variables")

# %%
llm = GoogleGenerativeAI(model='gemini-2.0-flash', temperature=0.9, google_api_key=api_key)

# %%
from langchain_google_genai import GoogleGenerativeAI
from langchain_core.prompts import PromptTemplate
from langchain.chains import LLMChain
import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()
api_key="AIzaSyDT9xCJmJ9-KroeDsNC8Fnt_j468ozBA9s"
# api_key = os.getenv('GEMINI_API_KEY')
if not api_key:
    raise ValueError("GEMINI_API_KEY not found in environment variables")
print(api_key)
# Initialize the Gemini LLM via LangChain
llm = GoogleGenerativeAI(
    model='gemini-2.0-flash',
    temperature=0.9,
    google_api_key=api_key
)

# Define the PromptTemplate with a transcript variable
template = '''You are a precise JSON extractor for patient appointment information. Follow these guidelines:

1. Extract the following fields from the given conversation:
    - name: Full name of the patient (string)
    - phone: Patient's contact phone number (string)
    - doctor: Name of the doctor (string)
    - timeSlot: Scheduled appointment time (string)

2. Parsing Rules:
    - Be case-sensitive and exact in capturing information
    - Remove any extra whitespace
    - Standardize phone number format (e.g., XXX-XXX-XXXX)
    - If ANY required field is missing, return null for the entire JSON object

3. Output Format:
    {{
      "name": "Patient Name" or null,
      "phone": "Phone Number" or null,
      "doctor": "Doctor Name" or null,
      "timeSlot": "Appointment Time" or null
    }}

Example Input: "Hi, I want to book an appointment with Dr. Smith for John Doe at 2 PM tomorrow. His number is 555-1234."
Example Output: 
{{
  "name": "John Doe",
  "phone": "555-1234",
  "doctor": "Dr. Smith", 
  "timeSlot": "2 PM tomorrow"
}}

Now extract the information from this conversation:
{transcript}
'''

prompt = PromptTemplate.from_template(template)

# Example conversation input (replace this with your real transcript)
transcript = "I’d like to book an appointment with Dr. Ramesh for Rajeev at 11 AM next Monday. His number is 987-654-3210."

# Construct the chain
chain = LLMChain(llm=llm, prompt=prompt, verbose=False)

# Invoke the chain with input
result = chain.invoke({"transcript": transcript})

# Print the result
print(result["text"])
# Out:
# AIzaSyDT9xCJmJ9-KroeDsNC8Fnt_j468ozBA9s
# ```json
# {
#   "name": "Rajeev",
#   "phone": "987-654-3210",
#   "doctor": "Dr. Ramesh",
#   "timeSlot": "11 AM next Monday"
# }
# ```
